# %%
d = dict()

# %%
print(d)
# Out:
# {}

# %%
d['1 rupee coins'] = 10
d['2 rupees coins'] = 5
d['5 rupees coins'] = 6
d['10 rupees coins'] = 12

# %%
print(d)
# Out:
# {'1 rupee coins': 10, '2 rupees coins': 5, '5 rupees coins': 6, '10 rupees coins': 12}

# %%
print(d['1 rupee coins'])
# Out:
# 10

# %%
print(d['5 rupees coins']+d['10 rupees coins'])
# Out:
# 18

# %%
d = { 'one' : 1 , 'two' : 2, 'three' : 3, 'four': 4 }

# %%
print(d)
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
print(len(d))
# Out:
# 4

# %%
print('three' in d)
# Out:
# True

# %%
print(4 in d)
# Out:
# False

# %%
print(5 in d and 2 in d)
# Out:
# False

# %%
def dict_func(word_cnt):
    counts = {}
    lst = word_cnt.split()
    for i in lst:
        counts[i] = 1 + counts.get(i, 0)
    return counts

# %%
dict_func("This is Cloudxlab which is a lab")
# Out:
# {'This': 1, 'is': 2, 'Cloudxlab': 1, 'which': 1, 'a': 1, 'lab': 1}

# %%
t = (1,)

# %%
print(t)
# Out:
# (1,)

# %%
type(t)
# Out:
# tuple

# %%
t = tuple()
print(t)
# Out:
# ()

# %%
t1 = tuple("1,2,3,4,5")
t2 = tuple([1,2,3,4,5])
t3 = tuple((1,2,3,4,5))

# %%
len(t1)
# Out:
# 9

# %%
t = (1,3,5,2,54,34,2,34,5)
l = len(t)
print(t[l-2])
# Out:
# 34

# %%
t2 = t[2:5]

# %%
sum_tup = 0
for i in t2:
    sum_tup = sum_tup + i
print(sum_tup)
# Out:
# 61

# %%
t3 = t[1:3] + t2[:]

# %%
sum_tup = 0
for i in t3:
    sum_tup = sum_tup + i
print(sum_tup)
# Out:
# 69

# %%
l = [(0,23,34), (2,34,23), (1,34,23)]
l.sort()

# %%
print(l)
# Out:
# [(2, 34, 23), (1, 34, 23), (0, 23, 34)]

# %%
sum_tup = 0
for i in l[2]:
    sum_tup = sum_tup + i
print(sum_tup)
# Out:
# 59

# %%
l.sort(reverse=True)

# %%
l = [1,2,3]
(a,b,c) = l

# %%
print(l)
# Out:
# [1, 2, 3]

# %%
print((a,b,c))
# Out:
# (1, 2, 3)

# %%
d = { "one" : 1, "two" : 2, "three" : 3}
k = d.items()
print(k)
# Out:
# dict_items([('one', 1), ('two', 2), ('three', 3)])

# %%
l = list(k)

# %%
print(l)
# Out:
# [('one', 1), ('two', 2), ('three', 3)]

# %%
for key, value in l:
    print(key, value)
# Out:
# one 1
# two 2
# three 3

# %%
def dict_tuple_func(lst_int):
    counts = {}
    sum_unique = 0
    int_comp = 0
    for x in lst_int:
        counts[x] = counts.get(x, 0) + 1
    
        
    
    
    
    
    
    
    
    
    
    for y in lst_int:
        if y == int_comp:
            int_comp = int_comp
            print(int_comp)
        else:
            int_comp = y
            print(int_comp)
    print(counts)
    print(int_comp)

# %%
dict_tuple_func([1,2,3,1,4])
# Out:
# 1
# 2
# 3
# 1
# 4
# {1: 2, 2: 1, 3: 1, 4: 1}
# 4

# %%
x = [2, 3, 1, 1, 2]
addo = 0
for i in range(0, len(x)):
    abc = 0
    if x[i] != addo:
        addo = i
    else:
        abc =

# %%
def dict_tuple_func(lst_int):
    counts = {}
    sum_unique = 0
    int_comp = 0
    for x in lst_int:
        counts[x] = counts.get(x, 0) + 1   
    #print(counts)
    sum_unique_values = sum(counts.keys())
    tup_dictNunique = (counts, sum_unique_values)
    return tup_dictNunique

# %%
dict_tuple_func([1,2,3,1,2])
# Out:
# ({1: 2, 2: 2, 3: 1}, 6)

# %%
dir.get()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-055710df897b> in <module>
# ----> 1 dir.get()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'get'

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'dict_tuple_func',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
def dict_tuple_func(lst_int):
    counts = {}
    sum_unique = 0
    int_comp = 0
    for x in lst_int:
        
    
    
    
    
    for x in lst_int:
        counts[x] = counts.get(x, 0) + 1   
    #print(counts)
    sum_unique_values = sum(counts.keys())
    tup_dictNunique = (counts, sum_unique_values)
    return tup_dictNunique

# %%
#unique numbers from the list
lst = [1,2,3,1,2]
sum_unique = 0
new_lst = []
for x in lst:
    if x not in new_lst:
        new_lst.append(x)
print(new_lst)
sum(new_lst)
# Out:
# [1, 2, 3]
# 6

# %%
x = [1,2]
1 not in x
# Out:
# False

# %%
lst = [1,2,3,1,2]
sum_unique = 0
new_lst = []
for x in lst:
    if x not in new_lst:
        new_lst.append(x)
        sum_unique = sum_unique + x
        
print(new_lst)
#sum(new_lst)
print(sum_unique)
# Out:
# [1, 2, 3]
# 6

# %%
lst=[1,2,3,1,2]
sum=0
count=0
count2=0
for i in lst:
    print(i)
    if count==0:
        sum=sum+i
        count=count+1
        print('Hello')
        
    else:
        exist=0
        print(count2)
        while count2 !=0:
            if lst[count2-1]==i:
                exist=1
                count2=count2-1
                print('Hi')
            else:
                exit
        if exist!=1:
            sum=sum+i
            count2=count2+1
            print('Hey')
print(sum)
# Out:
# 1
# Hello
# 2
# 0
# Hey
# 3
# 1

# %%
sum_unique
# Out:
# 6

# %%
## using re.search() like startswith()

import re

re.findall("[0-9]+\\.[0-9]+", "this is a singing 12 34 45s that 19.244234a aa")

re.findall("a", "this is a singing 12 34 45s that 19.244234a aa")
# Out:
# ['a', 'a', 'a', 'a', 'a']

# %%
#Network Programming

from urllib import *

fhand = request.urlopen('http://www.py4inf.com/code/romeo.txt')

for line in fhand:
    print()

# %%
#Beautifu Soup
from urllib import *
from bs4 import BeautifulSoup

url = input("Enter - ")
html = request.urlopen(url).read()
soup = BeautifulSoup(html)

tags = soup('a')

for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - https://www.wikipedia.org
# //en.wikipedia.org/
# //ja.wikipedia.org/
# //es.wikipedia.org/
# //de.wikipedia.org/
# //ru.wikipedia.org/
# //fr.wikipedia.org/
# //it.wikipedia.org/
# //zh.wikipedia.org/
# //pt.wikipedia.org/
# //pl.wikipedia.org/
# //ar.wikipedia.org/
# //de.wikipedia.org/
# //en.wikipedia.org/
# //es.wikipedia.org/
# //fr.wikipedia.org/
# //it.wikipedia.org/
# //nl.wikipedia.org/
# //ja.wikipedia.org/
# //pl.wikipedia.org/
# //pt.wikipedia.org/
# //ru.wikipedia.org/
# //ceb.wikipedia.org/
# //sv.wikipedia.org/
# //uk.wikipedia.org/
# //vi.wikipedia.org/
# //war.wikipedia.org/
# //zh.wikipedia.org/
# //ast.wikipedia.org/
# //az.wikipedia.org/
# //bg.wikipedia.org/
# //zh-min-nan.wikipedia.org/
# //be.wikipedia.org/
# //ca.wikipedia.org/
# //cs.wikipedia.org/
# //cy.wikipedia.org/
# //da.wikipedia.org/
# //et.wikipedia.org/
# //el.wikipedia.org/
# //eo.wikipedia.org/
# //eu.wikipedia.org/
# //fa.wikipedia.org/
# //gl.wikipedia.org/
# //hy.wikipedia.org/
# //hi.wikipedia.org/
# //hr.wikipedia.org/
# //id.wikipedia.org/
# //he.wikipedia.org/
# //ka.wikipedia.org/
# //la.wikipedia.org/
# //lv.wikipedia.org/
# //lt.wikipedia.org/
# //hu.wikipedia.org/
# //mk.wikipedia.org/
# //arz.wikipedia.org/
# //ms.wikipedia.org/
# //min.wikipedia.org/
# //no.wikipedia.org/
# //nn.wikipedia.org/
# //ce.wikipedia.org/
# //uz.wikipedia.org/
# //kk.wikipedia.org/
# //ro.wikipedia.org/
# //simple.wikipedia.org/
# //sk.wikipedia.org/
# //sl.wikipedia.org/
# //sr.wikipedia.org/
# //sh.wikipedia.org/
# //fi.wikipedia.org/
# //ta.wikipedia.org/
# //tt.wikipedia.org/
# //th.wikipedia.org/
# //tg.wikipedia.org/
# //azb.wikipedia.org/
# //tr.wikipedia.org/
# //ur.wikipedia.org/
# //vo.wikipedia.org/
# //ko.wikipedia.org/
# //ace.wikipedia.org/
# //af.wikipedia.org/
# //als.wikipedia.org/
# //am.wikipedia.org/
# //an.wikipedia.org/
# //bn.wikipedia.org/
# //map-bms.wikipedia.org/
# //ba.wikipedia.org/
# //be-tarask.wikipedia.org/
# //bcl.wikipedia.org/
# //bpy.wikipedia.org/
# //bar.wikipedia.org/
# //bs.wikipedia.org/
# //br.wikipedia.org/
# //cv.wikipedia.org/
# //nv.wikipedia.org/
# //eml.wikipedia.org/
# //fo.wikipedia.org/
# //fy.wikipedia.org/
# //ga.wikipedia.org/
# //gd.wikipedia.org/
# //gu.wikipedia.org/
# //hsb.wikipedia.org/
# //io.wikipedia.org/
# //ilo.wikipedia.org/
# //ia.wikipedia.org/
# //os.wikipedia.org/
# //is.wikipedia.org/
# //jv.wikipedia.org/
# //kn.wikipedia.org/
# //ht.wikipedia.org/
# //ku.wikipedia.org/
# //ckb.wikipedia.org/
# //ky.wikipedia.org/
# //mrj.wikipedia.org/
# //lb.wikipedia.org/
# //li.wikipedia.org/
# //lmo.wikipedia.org/
# //mai.wikipedia.org/
# //mg.wikipedia.org/
# //ml.wikipedia.org/
# //zh-classical.wikipedia.org/
# //mr.wikipedia.org/
# //xmf.wikipedia.org/
# //mzn.wikipedia.org/
# //cdo.wikipedia.org/
# //mn.wikipedia.org/
# //my.wikipedia.org/
# //new.wikipedia.org/
# //ne.wikipedia.org/
# //nap.wikipedia.org/
# //frr.wikipedia.org/
# //oc.wikipedia.org/
# //mhr.wikipedia.org/
# //or.wikipedia.org/
# //pa.wikipedia.org/
# //pnb.wikipedia.org/
# //ps.wikipedia.org/
# //pms.wikipedia.org/
# //nds.wikipedia.org/
# //qu.wikipedia.org/
# //sa.wikipedia.org/
# //sah.wikipedia.org/
# //sco.wikipedia.org/
# //sq.wikipedia.org/
# //scn.wikipedia.org/
# //si.wikipedia.org/
# //sd.wikipedia.org/
# //szl.wikipedia.org/
# //su.wikipedia.org/
# //sw.wikipedia.org/
# //tl.wikipedia.org/
# //te.wikipedia.org/
# //bug.wikipedia.org/
# //vec.wikipedia.org/
# //wa.wikipedia.org/
# //wuu.wikipedia.org/
# //yi.wikipedia.org/
# //yo.wikipedia.org/
# //zh-yue.wikipedia.org/
# //diq.wikipedia.org/
# //bat-smg.wikipedia.org/
# //kbd.wikipedia.org/
# //ang.wikipedia.org/
# //ab.wikipedia.org/
# //hyw.wikipedia.org/
# //roa-rup.wikipedia.org/
# //frp.wikipedia.org/
# //ig.wikipedia.org/
# //arc.wikipedia.org/
# //gn.wikipedia.org/
# //av.wikipedia.org/
# //ay.wikipedia.org/
# //bjn.wikipedia.org/
# //bh.wikipedia.org/
# //bi.wikipedia.org/
# //bo.wikipedia.org/
# //bxr.wikipedia.org/
# //cbk-zam.wikipedia.org/
# //co.wikipedia.org/
# //za.wikipedia.org/
# //se.wikipedia.org/
# //pdc.wikipedia.org/
# //dsb.wikipedia.org/
# //myv.wikipedia.org/
# //ext.wikipedia.org/
# //hif.wikipedia.org/
# //fur.wikipedia.org/
# //gv.wikipedia.org/
# //gag.wikipedia.org/
# //ki.wikipedia.org/
# //glk.wikipedia.org/
# //gan.wikipedia.org/
# //hak.wikipedia.org/
# //xal.wikipedia.org/
# //ha.wikipedia.org/
# //haw.wikipedia.org/
# //ie.wikipedia.org/
# //pam.wikipedia.org/
# //csb.wikipedia.org/
# //kw.wikipedia.org/
# //km.wikipedia.org/
# //rw.wikipedia.org/
# //kv.wikipedia.org/
# //kg.wikipedia.org/
# //gom.wikipedia.org/
# //gcr.wikipedia.org/
# //lo.wikipedia.org/
# //lad.wikipedia.org/
# //lbe.wikipedia.org/
# //lez.wikipedia.org/
# //ln.wikipedia.org/
# //jbo.wikipedia.org/
# //lrc.wikipedia.org/
# //lg.wikipedia.org/
# //lij.wikipedia.org/
# //mt.wikipedia.org/
# //ty.wikipedia.org/
# //mi.wikipedia.org/
# //mwl.wikipedia.org/
# //mdf.wikipedia.org/
# //nah.wikipedia.org/
# //na.wikipedia.org/
# //nds-nl.wikipedia.org/
# //nrm.wikipedia.org/
# //nov.wikipedia.org/
# //as.wikipedia.org/
# //pi.wikipedia.org/
# //pag.wikipedia.org/
# //pap.wikipedia.org/
# //koi.wikipedia.org/
# //pfl.wikipedia.org/
# //pcd.wikipedia.org/
# //krc.wikipedia.org/
# //kaa.wikipedia.org/
# //crh.wikipedia.org/
# //ksh.wikipedia.org/
# //rm.wikipedia.org/
# //rue.wikipedia.org/
# //sc.wikipedia.org/
# //stq.wikipedia.org/
# //nso.wikipedia.org/
# //sn.wikipedia.org/
# //so.wikipedia.org/
# //srn.wikipedia.org/
# //kab.wikipedia.org/
# //roa-tara.wikipedia.org/
# //tet.wikipedia.org/
# //tpi.wikipedia.org/
# //to.wikipedia.org/
# //tk.wikipedia.org/
# //tyv.wikipedia.org/
# //udm.wikipedia.org/
# //ug.wikipedia.org/
# //vep.wikipedia.org/
# //fiu-vro.wikipedia.org/
# //vls.wikipedia.org/
# //wo.wikipedia.org/
# //xh.wikipedia.org/
# //zea.wikipedia.org/
# //zu.wikipedia.org/
# //dv.wikipedia.org/
# //ak.wikipedia.org/
# //bm.wikipedia.org/
# //ch.wikipedia.org/
# //ny.wikipedia.org/
# //ee.wikipedia.org/
# //ff.wikipedia.org/
# //got.wikipedia.org/
# //iu.wikipedia.org/
# //ik.wikipedia.org/
# //kl.wikipedia.org/
# //ks.wikipedia.org/
# //ltg.wikipedia.org/
# //fj.wikipedia.org/
# //cr.wikipedia.org/
# //pih.wikipedia.org/
# //om.wikipedia.org/
# //pnt.wikipedia.org/
# //dz.wikipedia.org/
# //rmy.wikipedia.org/
# //rn.wikipedia.org/
# //sm.wikipedia.org/
# //sg.wikipedia.org/
# //st.wikipedia.org/
# //tn.wikipedia.org/
# //cu.wikipedia.org/
# //ss.wikipedia.org/
# //chr.wikipedia.org/
# //chy.wikipedia.org/
# //ve.wikipedia.org/
# //ts.wikipedia.org/
# //tum.wikipedia.org/
# //tw.wikipedia.org/
# //ti.wikipedia.org/
# //nqo.wikipedia.org/
# //meta.wikimedia.org/wiki/List_of_Wikipedias
# //de.wikipedia.org/wiki/Wikipedia:Sprachen
# //meta.wikimedia.org/wiki/Liste_des_Wikip%C3%A9dias
# //pl.wikipedia.org/wiki/Wikipedia:Lista_wersji_j%C4%99zykowych
# //ja.wikipedia.org/wiki/Wikipedia:%E5%A4%9A%E8%A8%80%E8%AA%9E%E3%83%97%E3%83%AD%E3%82%B8%E3%82%A7%E3%82%AF%E3%83%88%E3%81%A8%E3%81%97%E3%81%A6%E3%81%AE%E3%82%A6%E3%82%A3%E3%82%AD%E3%83%9A%E3%83%87%E3%82%A3%E3%82%A2
# //meta.wikimedia.org/wiki/Lista_de_Wikipedias
# //zh.wikipedia.org/wiki/Wikipedia:%E7%BB%B4%E5%9F%BA%E7%99%BE%E7%A7%91%E8%AF%AD%E8%A8%80%E5%88%97%E8%A1%A8
# //ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BF%D0%B5%D0%B4%D0%B8%D1%8F:%D0%A1%D0%92
# //eo.wikipedia.org/wiki/Vikipedio:Internacia_Vikipedio
# //meta.wikimedia.org/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC%EC%9D%98_%EB%AA%A9%EB%A1%9D
# //vi.wikipedia.org/wiki/Wikipedia:Phi%C3%AAn_b%E1%BA%A3n_ng%C3%B4n_ng%E1%BB%AF
# //wikimediafoundation.org/
# https://en.wikipedia.org/wiki/List_of_Wikipedia_mobile_applications
# //play.google.com/store/apps/details?id=org.wikipedia&referrer=utm_source%3Dportal%26utm_medium%3Dbutton%26anid%3Dadmob
# //itunes.apple.com/app/apple-store/id324715238?pt=208305&ct=portal&mt=8
# //commons.wikimedia.org/
# //www.wikivoyage.org/
# //www.wiktionary.org/
# //www.wikibooks.org/
# //www.wikinews.org/
# //www.wikidata.org/
# //www.wikiversity.org/
# //www.wikiquote.org/
# //www.mediawiki.org/
# //www.wikisource.org/
# //species.wikimedia.org/
# //meta.wikimedia.org/
# https://creativecommons.org/licenses/by-sa/3.0/
# //meta.wikimedia.org/wiki/Terms_of_Use
# //meta.wikimedia.org/wiki/Privacy_policy

# %%
#Classes and Objects

class PartyAnimal():
    x = 0
    
    def party(self):
        self.x = self.x + 1
        print(self.x)

# %%
an = PartyAnimal()

an.party()
an.party()
an.party()
# Out:
# 1
# 2
# 3

# %%
so = PartyAnimal()

so.party()
# Out:
# 1

# %%
pip3 install requests
# Out:
#   File "<ipython-input-3-7fed49db49d4>", line 1
#     pip3 install requests
#                ^
# SyntaxError: invalid syntax

# %%
import requests
import sys
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from urllib.parse import urljoin

searched_links = []
broken_links = []

def getLinksFromHTML(html):
    def getLink(el):
        return el["href"]
    return list(map(getLink, BeautifulSoup(html, features="html.parser").select("a[href]")))

def find_broken_links(domainToSearch, URL, parentURL):
    if (not (URL in searched_links)) and (not URL.startswith("mailto:")) and (not ("javascript:" in URL)) and (not URL.endswith(".png")) and (not URL.endswith(".jpg")) and (not URL.endswith(".jpeg")):
        try:
            requestObj = requests.get(URL);
            searched_links.append(URL)
            if(requestObj.status_code == 404):
                broken_links.append("BROKEN: link " + URL + " from " + parentURL)
                print(broken_links[-1])
            else:
                print("NOT BROKEN: link " + URL + " from " + parentURL)
                if urlparse(URL).netloc == domainToSearch:
                    for link in getLinksFromHTML(requestObj.text):
                        find_broken_links(domainToSearch, urljoin(URL, link), URL)
        except Exception as e:
            print("ERROR: " + str(e));
            searched_links.append(domainToSearch)

find_broken_links(urlparse(sys.argv[1]).netloc, sys.argv[1], "")

print("\n--- DONE! ---\n")
print("The following links were broken:")

for link in broken_links:
    print ("\t" + link)
# Out:
# ERROR: Invalid URL '-f': No schema supplied. Perhaps you meant http://-f?
#
# --- DONE! ---
#
# The following links were broken:

# %%
from bs4 import BeautifulSoup,SoupStrainer
import urllib.request
import colorama,re,queue,threading
from colorama import Fore
from urllib.parse import *

class check_link():
    def __init__(self,address):
        self.address=address        
    def check(self,address):   
        try:
            req=urllib.request.Request(url=address)
            resp=urllib.request.urlopen(req)
            if resp.status in [400,404,403,408,409,501,502,503]:print (Fore.RED+resp.status+"-"+resp.reason+"-->"+address)               
            else: print (Fore.GREEN+"no problem in-->"+address)
                              
        except Exception as e:
            print (Fore.YELLOW+"{}-{}".format(e,address))
            pass   
def pattern_adjust(a):  
    try:
        if re.match('^#' ,a):return 0 
        r=urlsplit(a)
        if r.scheme=='' and (r.netloc!='' or r.path!=''):
            d=urlunsplit(r)
            if re.match('^//' ,d):
                m= re.search('(?<=//)\S+', d)
                d=m.group(0)  
                m="https://"+d
                return m
        elif r.scheme=='' and r.netloc=='':
            return address+a
        else:return a
    except Exception as e:
        pass
def extract_link(address):
    tags= {'a':'href', 'img':'src', 'script':'src', 'link':'href' }
    for key,value in iter(tags.items()):    
        try:
            res=urllib.request.urlopen(address)
            response=res.read().decode('utf-8') #needs improvement
            for link in BeautifulSoup(response,"html.parser",parse_only=SoupStrainer(key)): 
                if link.has_attr(value):
                    p=pattern_adjust(link[value])
                    if p!=0 and str(p)!='None':        
                        newcheck=check_link(p)
                        newcheck.check(p)
                        if p not in hyperlinks:
                            hyperlinks.add(p)
                            if website.split('.')[1] in p:#needs improvement
                                if not website.endswith(('.png','.jpeg','.js','jpg')):
                                    q.put(p)                    
        except Exception as e:
            print (e,address)                                
def threader():
    while True:
        value=q.get()  
        result=extract_link(value)
        q.task_done()

if __name__=="__main__":
    colorama.init()
    q=queue.Queue()
    global hyperlinks,website
    hyperlinks=set()
    website=input("Please enter the website address: ") 
    for x in range(30):
        t=threading.Thread(target=threader)
        t.deamon=True
        t.start()   
    q.put(website.strip())
    q.join()
# Out:
# Please enter the website address: https://www.gatewayhouse.in
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/wiki/index.php?title=Main_Page&oldid=14
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->http://www.gatewayhouse.in/wiki/index.php?title=Main_Page&oldid=14
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->http://www.gatewayhouse.in/about-us
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/about-us
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->http://www.gatewayhouse.in/experts
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->http://www.gatewayhouse.in/experts
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/regions
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->http://www.gatewayhouse.in/regions
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->http://www.gatewayhouse.in/issues
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->http://www.gatewayhouse.in/issues
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/publications
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->http://www.gatewayhouse.in/events
# no problem in-->http://www.gatewayhouse.in/publications
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->http://www.gatewayhouse.in/voices
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->http://www.gatewayhouse.in/events
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->http://www.gatewayhouse.in/media
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# HTTP Error 404: Not Found-http://www.gatewayhouse.in/contactus
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# HTTP Error 404: Not Found http://www.gatewayhouse.in/contactus
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# HTTP Error 404: Not Found http://www.gatewayhouse.in/contactus
# no problem in-->https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# HTTP Error 404: Not Found http://www.gatewayhouse.in/contactus
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->http://www.gatewayhouse.in/voices
# HTTP Error 404: Not Found http://www.gatewayhouse.in/contactus
# no problem in-->https://www.mediawiki.org/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/media
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# HTTP Error 404: Not Found-http://www.gatewayhouse.in/contactus
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/wiki/load.php?debug=false&lang=en&modules=startup&only=scripts&skin=vector&*
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->http://www.gatewayhouse.in/wiki/api.php?action=rsd
# no problem in-->https://www.mediawiki.org/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->http://www.gatewayhouse.in/wiki/load.php?debug=false&lang=en&modules=mediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.ui.button%7Cskins.vector.styles&only=styles&skin=vector&*
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->http://www.gatewayhouse.in/wiki/load.php?debug=false&lang=en&modules=startup&only=scripts&skin=vector&*
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->http://www.gatewayhouse.in/wiki/api.php?action=rsd
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->http://www.gatewayhouse.in/wiki/load.php?debug=false&lang=en&modules=mediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.ui.button%7Cskins.vector.styles&only=styles&skin=vector&*
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
#
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
#
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/visiting-fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/researchers/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/regions/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/visiting-fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/regions/africa/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/regions/america/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/researchers/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/regions/asia/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/regions/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/no problem in-->https://www.gatewayhouse.in/testimonials/
#
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/visiting-fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/regions/europe/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/regions/africa/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/regions/global-commons/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/internships/
# no problem in-->https://www.gatewayhouse.in/regions/america/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/corporate-social-responsibility/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/fellowships/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/researchers/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/testimonials/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/visiting-fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/work-us/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# ...
#
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/images/devices/reverie-icon-ipad.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2020/06/IMG_9738.jpg
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/facebook-dreamstale25.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/twitter-dreamstale71.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/linkedin-dreamstale45.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/ios9-podcasts-app-tile.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/soundcloud-dreamstale63.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/youtube-dreamstale86.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/Untitled-3.png
# no problem in-->https://www.gatewayhouse.in/
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/feed-dreamstale27.png
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/china-coming-upheaval/
# no problem in-->https://www.gatewayhouse.in/publications/
# no problem in-->https://www.gatewayhouse.in/author/frank-schell/
# no problem in-->https://www.gatewayhouse.in/author/chaitanya-giri/
# no problem in-->https://www.gatewayhouse.in/issues/page/40/
# no problem in-->https://www.gatewayhouse.in/tag/e-commerce/
# no problem in-->https://www.gatewayhouse.in/china-coming-upheaval/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/publications/research-papers/papers/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/issues/
# no problem in-->https://www.gatewayhouse.in/goigd/
# no problem in-->https://www.gatewayhouse.in/publications/book-reviews/
# no problem in-->https://www.gatewayhouse.in/author/aditya-phatak/
# no problem in-->https://www.gatewayhouse.in/regions/page/80/
# no problem in-->https://www.gatewayhouse.in/myth-chinese-capitalism/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->http://www.facebook.com/home.php?#!/pages/Gateway-House-Indian-Council-on-Global-Relations/115292765164430?ref=ts
# no problem in-->https://www.gatewayhouse.in/author/amit-bhandari/
# no problem in-->http://twitter.com/gatewayhouseind
# HTTP Error 999: Request denied-https://www.linkedin.com/company/gateway-house-indian-council-of-global-relations?trk=mini-profile-title
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# HTTP Error 404: Not Found-https://itunes.apple.com/in/podcast/the-gateway-house-podcast/id1041689611
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://soundcloud.com/gateway-house-indian-council-on-global-relations
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/site-index/
# no problem in-->http://www.youtube.com/channel/UCRIjNjS_T48odMrxTylxIxg
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->https://plus.google.com/115924730915406257771
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.googletagmanager.com/gtag/js?id=UA-113984233-1
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.min.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/modernizr.foundation.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/position.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/sortable.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/fellows/
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/menu.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/autocomplete.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/resizable.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/draggable.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/button.min.js?ver=1.11.4
# no problem in-->http://www.icdindia.com/
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/dialog.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/events-manager/includes/js/events-manager.js?ver=5.6624
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/woocommerce/assets/js/frontend/add-to-cart.min.js?ver=2.4.12
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/js_composer/assets/js/vendors/woocommerce-add-to-cart.js?ver=4.8.0.1
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/wp-chgfontsize/wp-chgfontsize.js
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.reveal.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.orbit-1.4.0.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.customforms.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.placeholder.min.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.tooltips.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/app.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/myth-chinese-capitalism/
# no problem in-->https://www.gatewayhouse.in/tag/indian-space-station/
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/contact-form-7/includes/js/jquery.form.min.js?ver=3.51.0-2014.06.20
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=4.3.1
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/woocommerce/assets/js/jquery-blockui/jquery.blockUI.min.js?ver=2.70
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/woocommerce/assets/js/frontend/woocommerce.min.js?ver=2.4.12
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/woocommerce/assets/js/jquery-cookie/jquery.cookie.min.js?ver=1.4.1
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/woocommerce/assets/js/frontend/cart-fragments.min.js?ver=2.4.12
# no problem in-->https://www.gatewayhouse.in/tag/economy-2/
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/wp-polls/polls-js.js?ver=2.63
# no problem in-->http://www.facebook.com/home.php?#!/pages/Gateway-House-Indian-Council-on-Global-Relations/115292765164430?ref=ts
# no problem in-->https://www.gatewayhouse.in/china-coming-upheaval/
# no problem in-->https://www.gatewayhouse.in/
# no problem in-->http://twitter.com/gatewayhouseind
# HTTP Error 999: Request denied-https://www.linkedin.com/company/gateway-house-indian-council-of-global-relations?trk=mini-profile-title
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://madmimi.com/signups/75579/join
# HTTP Error 404: Not Found-https://itunes.apple.com/in/podcast/the-gateway-house-podcast/id1041689611
# no problem in-->https://www.gatewayhouse.in/publications/book-reviews/
# no problem in-->https://www.connect91.com
# no problem in-->https://www.gatewayhouse.in/issues/page/50/
# no problem in-->https://soundcloud.com/gateway-house-indian-council-on-global-relations
# no problem in-->https://www.gatewayhouse.in/space-exploration-industry-india/
# no problem in-->https://www.gatewayhouse.in/publications/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->http://www.youtube.com/channel/UCRIjNjS_T48odMrxTylxIxg
# no problem in-->https://plus.google.com/115924730915406257771
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/regions/page/90/
# no problem in-->https://www.gatewayhouse.in/goigd/
# no problem in-->https://www.gatewayhouse.in/publications/research-papers/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/myth-chinese-capitalism/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/
# no problem in-->https://www.gatewayhouse.in/regions/
# no problem in-->https://www.gatewayhouse.in/author/aditya-shirish-rao/
# no problem in-->https://www.gatewayhouse.in/
# no problem in-->https://www.gatewayhouse.in/tag/isro/
# no problem in-->https://www.gatewayhouse.in/tag/facebook/
# no problem in-->https://www.gatewayhouse.in/publications/book-reviews/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/myth-chinese-capitalism/
# no problem in-->https://www.gatewayhouse.in/author/aditya-shirish-rao/
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/favicon-32x32.png
# no problem in-->https://www.gatewayhouse.in/space-exploration-industry-india/
# no problem in-->https://www.gatewayhouse.in/issues/page/60/
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/images/gatewayhouse_logo.gif
# no problem in-->https://www.gatewayhouse.in/wp-content/plugins/wp-print/images/printer_famfamfam.gif
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2020/05/26-May_Space-Agenda-Cover-_Final.pngno problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-members/
#
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2020/04/00_fa_mj2020_cover.jpg
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2020/06/IMG_9738.jpg
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/facebook-dreamstale25.png
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/twitter-dreamstale71.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/linkedin-dreamstale45.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/ios9-podcasts-app-tile.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/soundcloud-dreamstale63.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/youtube-dreamstale86.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/Untitled-3.png
# no problem in-->https://www.gatewayhouse.in/wp-content/uploads/2016/12/feed-dreamstale27.png
# no problem in-->https://www.gatewayhouse.in/feed/
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/images/devices/reverie-icon-ipad.png
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founder-members/
# no problem in-->https://www.gatewayhouse.in/regions/page/100/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.gatewayhouse.in/gateway-house/past-events/
# no problem in-->https://www.gatewayhouse.in/publications/gh-in-the-media/
# no problem in-->https://www.gatewayhouse.in/about-us/participate/become-member/contact-us/
# no problem in-->https://madmimi.com/signups/75579/join
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/our-approach/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/
# no problem in-->https://www.gatewayhouse.in/issues/
# no problem in-->https://www.gatewayhouse.in/wiki/
# no problem in-->https://www.gatewayhouse.in/experts-list/internal/visiting-fellows/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/space-exploration-industry-india/
# no problem in-->https://www.gatewayhouse.in/about-us/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/faq/
# no problem in-->https://www.gatewayhouse.in/tag/privatisation-of-space-sector/
# no problem in-->https://www.gatewayhouse.in/myth-chinese-capitalism/
# no problem in-->https://www.gatewayhouse.in/tag/jio/
# no problem in-->https://www.gatewayhouse.in/site-index/
# no problem in-->https://www.gatewayhouse.in/regions/
# no problem in-->https://www.gatewayhouse.in/about-us/what-we-do/mission-and-goals/
# no problem in-->https://www.gatewayhouse.in/publications/partner-publication/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/key-staff-members/
# no problem in-->http://www.icdindia.com/
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/founders-message/
# no problem in-->https://www.googletagmanager.com/gtag/js?id=UA-113984233-1
# no problem in-->https://www.gatewayhouse.in/issues/page/70/
# no problem in-->https://www.gatewayhouse.in/about-us/how-you-benefit/outreach/
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/jquery.min.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/wp-content/themes/cornmedia/js/modernizr.foundation.js?ver=4.2.3
# no problem in-->https://www.gatewayhouse.in/regions/page/2/
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/about-us/who-we-are/our-board/
# no problem in-->https://www.gatewayhouse.in/author/frank-schell/no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4
#
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/position.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/sortable.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-23fdad1528ff> in <module>
#      70         t.start()
#      71     q.put(website.strip())
# ---> 72     q.join()
#
# /usr/local/anaconda/lib/python3.6/queue.py in join(self)
#      81         with self.all_tasks_done:
#      82             while self.unfinished_tasks:
# ---> 83                 self.all_tasks_done.wait()
#      84
#      85     def qsize(self):
#
# /usr/local/anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/menu.min.js?ver=1.11.4
# no problem in-->https://www.gatewayhouse.in/wp-includes/js/jquery/ui/autocomplete.min.js?ver=1.11.4

# %%
def special_func(num):
    total = 0
    if type(num) == int:
    #if num > 0:
        for i in range(1,num+1):
            if num % i == 0:
                if i % 2 != 0:
                    total = total + i
        #print(total)
        return total
    else:
        return -10

# %%
x = special_func('-190')
print(x)
# Out:
# -10

# %%
type(10) == int
# Out:
# True

# %%
head -n 15 /cxldata/datasets/project/mbox-short.txt
# Out:
#   File "<ipython-input-1-ceeca0e25398>", line 1
#     head -n 15 /cxldata/datasets/project/mbox-short.txt
#              ^
# SyntaxError: invalid syntax

# %%
fhand = open('/cxldata/datasets/project/mbox-short.txt')
inp = fhand.read()


count = 0
for i in inp:
    if i == '\n':
        count = count + 1
print(count)
# Out:
# 1910

# %%
def number_of_lines(inp):
    count = 0
    for i in inp:
        if i == '\n':
            count = count + 1
    return count

# %%
x = number_of_lines(inp)
print(x)
# Out:
# 1910

# %%
fhand.close()

# %%
#Python Project - Churn Emails - Count the Number of Lines
def number_of_lines():
    fhand = open('/cxldata/datasets/project/mbox-short.txt')
    inp = fhand.read()
    count = 0
    for i in inp:
        if i == '\n':
            count = count + 1
    return count
